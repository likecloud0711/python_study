# %%
#!/usr/bin/env python
# coding: utf-8

# In[6]:


import pandas as pd 

import requests   
from bs4 import BeautifulSoup


#[CODE 1]
#네이버 금융 국내증시 상위100의 기업 이름과 url 크롤링
def get_top100(top100_url, top100_name):
    url = 'https://finance.naver.com/sise/sise_quant.nhn'
    result = requests.get(url)
    html = BeautifulSoup(result.content, 'html.parser')

    top100 = html.find_all('a', {'class':'tltle'})

    for i in range(100):
        url = 'https://finance.naver.com' + top100[i]['href']    
        top100_url.append(url)
    
        company_name = top100[i].string    
        top100_name.append(company_name)

    return (top100_url, top100_name)


#[CODE 2] 검색할 기업 입력받기
def get_company(top100_name):
    company_name = input('주가를 검색할 기업이름을 입력하세요: ')

    for i in range(101):
        if i == 100:
            return(100)
        if company_name == top100_name[i]:            
            return(i)            

#[CODE 3]
# company_url에 대한 기업 주식 정보 페이지 크롤링
def get_company_stockPage(company_url):    
    result = requests.get(company_url)
    company_stockPage = BeautifulSoup(result.content, "html.parser")
    return company_stockPage


#[CODE 4] 
# 기업의 현재 주가 데이터 크롤링
def get_price(company_url):
    company_stockPage = get_company_stockPage(company_url) #[CODE 3]
    no_today = company_stockPage.find("p", {"class": "no_today"})
    blind = no_today.find("span", {"class": "blind"})
    now_price = blind.text
    return now_price


#[CODE 0]
def main():
    top100_url=[]
    top100_name = []

    top100_url, top100_name = get_top100(top100_url, top100_name) #[CODE 1]

    print("< 현재 네이버 금융 국내 코스피 상위100 기업 목록 >")
    print(top100_name)
    print('')

    company = int(get_company(top100_name))  #[CODE 2]
    if company == 100:
        print("입력한 기업은 상위100 목록에 없습니다.")        
    else :        
        now_price = get_price(top100_url[company]) #[CODE 4]
        print('%s 기업의 현재 주가는 %s 입니다' % (top100_name[company], now_price))


if __name__ == '__main__':
     main()
# Out:
# < 현재 네이버 금융 국내 코스피 상위100 기업 목록 >
# ['KODEX 200선물인버스2X', '에이프로젠', '베트남개발1', 'KODEX 코스닥150선물인버스', '대한전선', '대호에이엘', 'KODEX 인버스', 'KODEX 레버리지', 'KODEX 코스닥150레버리지', '이엔플러스', '인디에프', '대원강업', '태평양물산', '큐로', '태림포장', '삼성전자', 'IHQ', '신한 인버스 2X WTI원유 선물 ETN(H)', '신풍제약', '카카오뱅크', '세원이앤씨', '서연', '일동제약', 'TRUE 인버스 2X 천연가스 선물 ETN(H)', 'KH 필룩스', 'STX', 'TIGER 200선물인버스2X', '현대두산인프라코어', '에이프로젠제약', '세우글로벌', 'KODEX 코스닥150', '한국카본', '두산에너빌리티', '이수페타시스', '인바이오젠', '삼성 인버스 2X 코스닥150 선물 ETN', '팬오션', '삼성 인버스 2X WTI원유 선물 ETN', '조일알미늄', 'TIGER 차이나전기차SOLACTIVE', '일진디스플', 'KODEX 200', '남성', '다이나믹디자인', '수산중공업', '금양', '현대리바트', '신한 인버스 2X 천연가스 선물 ETN', '이수화학', 'STX중공업', '국보', '카카오페이', 'DB하이텍', '일동홀딩스', '삼부토건', '서연이화', 'TIGER 인버스', '미래에셋 인버스 2X 코스피200 선물 ETN', '한미글로벌', 'STX엔진', '대창단조', 'QV 인버스 레버리지 WTI원유 선물 ETN(H)', '그린케미칼', '황금에스티', '카카오', 'KEC', 'KODEX WTI원유선물인버스(H)', 'TYM', 'TIGER 차이나항셍테크', '평화산업', 'KODEX 2차전지산업', '동원금속', 'LG헬로비전', 'SK하이닉스', '현대로템', '도화엔지니어링', '대한해운', 'TIGER 미국S&P500', '남선알미늄', '제이준코스메틱', 'KODEX 단기채권PLUS', '한화생명', '삼성중공업', '기아', 'HMM', '한화시스템', '코스모화학', '마니커', '쏘카', '태경비케이', '에스엘', '쌍방울', '한화솔루션', '후성', 'BNK금융지주', 'KODEX 차이나H레버리지(H)', 'KC코트렐', '티에이치엔', '부산주공', '유니온머티리얼']
#
# 주가를 검색할 기업이름을 입력하세요: 카카오페이
# 카카오페이 기업의 현재 주가는 62,600 입니다
