# %%
import requests
from bs4 import BeautifulSoup
 
RANK = 100 ## 멜론 차트 순위가 1 ~ 100위까지 있음
 
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get('https://www.melon.com/chart/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
html = req.text
parse = BeautifulSoup(html, 'html.parser')
 
titles = parse.find_all("div", {"class": "ellipsis rank01"}) 
singers = parse.find_all("div", {"class": "ellipsis rank02"}) 
albums = parse.find_all("div",{"class": "ellipsis rank03"})
 
title = []
singer = []
album = []
 
for t in titles:
    title.append(t.find('a').text)
 
for s in singers:
    singer.append(s.find('span', {"class": "checkEllipsis"}).text)

for a in albums:
    album.append(a.find('a').text)
 
for i in range(RANK):
    print('%3d위: %s [ %s ] - %s'%(i+1, title[i], album[i], singer[i]))
# Out:
#   1위: 사건의 지평선 [ YOUNHA 6th Album Repackage 'END THEORY : Final Edition' ] - 윤하 (YOUNHA)
#   2위: Nxde [ I love ] - (여자)아이들
#   3위: ANTIFRAGILE [ ANTIFRAGILE ] - LE SSERAFIM (르세라핌)
#   4위: Hype boy [ NewJeans 1st EP 'New Jeans' ] - NewJeans
#   5위: After LIKE [ After LIKE ] - IVE (아이브)
#   6위: 새삥 (Prod. ZICO) (Feat. 호미들) [ 스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) ] - 지코 (ZICO)
#   7위: Rush Hour (Feat. j-hope of BTS) [ Rush Hour ] - Crush
#   8위: Attention [ NewJeans 1st EP 'New Jeans' ] - NewJeans
#   9위: Shut Down [ BORN PINK ] - BLACKPINK
#  10위: Monologue [ Monologue ] - 테이
#  11위: LOVE DIVE [ LOVE DIVE ] - IVE (아이브)
#  12위: 자격지심 (Feat. ZICO) [ FIVE SENSES ] - BE'O (비오)
#  13위: Pink Venom [ BORN PINK ] - BLACKPINK
#  14위: 사랑은 늘 도망가 [ 신사와 아가씨 OST Part.2 ] - 임영웅
#  15위: 딱 10CM만 [ 딱 10CM만 ] - 10CM, BIG Naughty (서동현)
#  16위: 우리들의 블루스 [ IM HERO ] - 임영웅
#  17위: 그때 그 순간 그대로 (그그그) [ WSG워너비 1집 ] - WSG워너비 (가야G)
#  18위: TOMBOY [ I NEVER DIE ] - (여자)아이들
#  19위: 해요 (2022) [ 해요 (2022) ] - #안녕
#  20위: 우린 그렇게 사랑해서 [ 우린 그렇게 사랑해서 ] - 강민경 (다비치), 잔나비 최정훈
#  21위: 그라데이션 [ 5.3 ] - 10CM
#  22위: 다시 만날 수 있을까 [ IM HERO ] - 임영웅
#  23위: Cookie [ NewJeans 1st EP 'New Jeans' ] - NewJeans
#  24위: 사랑인가 봐 [ 사랑인가 봐 (사내맞선 OST 스페셜 트랙) ] - 멜로망스
#  25위: 내가 아니라도 [ 내가 아니라도 ] - 주호
#  26위: 정이라고 하자 (Feat. 10CM) [ 정이라고 하자 ] - BIG Naughty (서동현)
#  27위: 보고싶었어 [ WSG워너비 1집 ] - WSG워너비 (4FIRE)
#  28위: 무지개 [ IM HERO ] - 임영웅
#  29위: FEARLESS [ FEARLESS ] - LE SSERAFIM (르세라핌)
#  30위: 이제 나만 믿어요 [ 내일은 미스터트롯 우승자 특전곡 ] - 임영웅
#  31위: 나의 X에게 [ 나의 X에게 ] - 경서
#  32위: 너의 모든 순간 [ 별에서 온 그대 OST Part.7 ] - 성시경
#  33위: 아버지 [ IM HERO ] - 임영웅
#  34위: ELEVEN [ ELEVEN ] - IVE (아이브)
#  35위: That That (prod. & feat. SUGA of BTS) [ 싸다9 ] - 싸이 (PSY)
#  36위: 취중고백 [ 취중고백 ] - 김민석 (멜로망스)
#  37위: That's Hilarious [ CHARLIE ] - Charlie Puth
#  38위: FOREVER 1 [ FOREVER 1 - The 7th Album ] - 소녀시대 (GIRLS' GENERATION)
#  39위: A bientot [ IM HERO ] - 임영웅
#  40위: 다정히 내 이름을 부르면 [ 다정히 내 이름을 부르면 (경서예지 x 전건호) ] - 경서예지, 전건호
#  41위: 떠나보낼 준비해 둘걸 그랬어 [ 떠나보낼 준비해 둘걸 그랬어 ] - 임한별
#  42위: 내 기쁨은 너가 벤틀리를 끄는 거야 [ PROTOTYPE RESEARCH #0063 ] - 김승민
#  43위: LOVE me [ LOVE me ] - BE'O (비오)
#  44위: 손이 참 곱던 그대 [ IM HERO ] - 임영웅
#  45위: 인생찬가 [ IM HERO ] - 임영웅
#  46위: 사랑해 진짜 [ IM HERO ] - 임영웅
#  47위: LAW (Prod. Czaer) [ 스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) ] - 윤미래, 비비 (BIBI)
#  48위: SNEAKERS [ CHECKMATE ] - ITZY (있지)
#  49위: I Don't Think That I Like Her [ CHARLIE ] - Charlie Puth
#  50위: 연애편지 [ IM HERO ] - 임영웅
#  51위: 새벽에 걸려온 너의 전화는 [ 미련을 말하는 ] - 한동근
#  52위: Dynamite [ Dynamite (DayTime Version) ] - 방탄소년단
#  53위: 도깨비불 (Illusion) [ Girls - The 2nd Mini Album ] - aespa
#  54위: 사랑역 [ IM HERO ] - 임영웅
#  55위: Love story [ Seoul ] - 볼빨간사춘기
#  56위: 모든 날, 모든 순간 (Every day, Every Moment) [ '키스 먼저 할까요?' OST Part.3 ] - 폴킴
#  57위: 보금자리 [ IM HERO ] - 임영웅
#  58위: 사랑해요 그대를 [ IM HERO ] - 임영웅
#  59위: Left and Right (Feat. Jung Kook of BTS) [ Left and Right (Feat. Jung Kook of BTS) ] - Charlie Puth, 정국, 방탄소년단
#  60위: STAY [ Stay ] - The Kid LAROI, Justin Bieber
#  61위: 봄여름가을겨울 (Still Life) [ 봄여름가을겨울 (Still Life) ] - BIGBANG (빅뱅)
#  62위: POP! [ IM NAYEON ] - 나연 (TWICE)
#  63위: 밤하늘의 별을(2020) [ 밤하늘의 별을(2020) ] - 경서
#  64위: 사랑한다고 말해줘 [ 사랑한다고 말해줘 ] - 탑현
#  65위: Butter [ Butter ] - 방탄소년단
#  66위: 주저하는 연인들을 위해 [ 전설 ] - 잔나비
#  67위: 스티커 사진 [ 스티커 사진 ] - 21학번
#  68위: 고백연습 [ 고백연습 ] - 경서
#  69위: 그래서 그대는 [ 그래서 그대는 ] - 이영현
#  70위: 봄날 [ YOU NEVER WALK ALONE ] - 방탄소년단
#  71위: The Astronaut [ The Astronaut ] - 진
#  72위: 첫사랑 [ 첫사랑 ] - 백아
#  73위: Feel My Rhythm [ ‘The ReVe Festival 2022 - Feel My Rhythm’ ] - Red Velvet (레드벨벳)
#  74위: strawberry moon [ strawberry moon ] - 아이유
#  75위: 신호등 [ 신호등 ] - 이무진
#  76위: Permission to Dance [ Butter / Permission to Dance ] - 방탄소년단
#  77위: Yet To Come [ Proof ] - 방탄소년단
#  78위: MY BAG [ I NEVER DIE ] - (여자)아이들
#  79위: 못해 [ 못해 (Re : WIND 4MEN Vol.02) ] - 김나영
#  80위: INVU [ INVU - The 3rd Album ] - 태연 (TAEYEON)
#  81위: 통화연결음 [ 통화연결음 ] - 보라미유, MJ (써니사이드)
#  82위: 내 손을 잡아 [ 최고의 사랑 OST Part.4 ] - 아이유
#  83위: Off My Face [ Justice (The Complete Edition) ] - Justin Bieber
#  84위: 드라마 [ 조각집 ] - 아이유
#  85위: 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈) [ 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈) ] - 이석훈
#  86위: Next Level [ Next Level ] - aespa
#  87위: Girls [ Girls - The 2nd Mini Album ] - aespa
#  88위: DICE [ ENTWURF ] - NMIXX
#  89위: 늦은 밤 헤어지긴 너무 아쉬워 [ LOVE & HATE ] - 케이시 (Kassy)
#  90위: 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom) [ 쇼미더머니 10 Episode 2 ] - sokodomo
#  91위: GANADARA (Feat. 아이유) [ GANADARA ] - 박재범
#  92위: 너를 생각해 [ 너를 생각해 ] - 주시크 (Joosiq)
#  93위: I Ain't Worried [ 탑건 : 매버릭 (Top Gun: Maverick) (영화 OST) ] - OneRepublic
#  94위: Talk that Talk [ BETWEEN 1&2 ] - TWICE (트와이스)
#  95위: 그중에 그대를 만나 [ 삼남매가 용감하게 OST Part.1 ] - 김호중
#  96위: 듣고 싶을까 [ 듣고 싶을까 ] - MSG워너비(M.O.M)
#  97위: Weekend [ Weekend ] - 태연 (TAEYEON)
#  98위: 아무래도 난 [ 아무래도 난 ] - 주시크 (Joosiq)
#  99위: 나의 목소리로 [ 나의 목소리로 ] - 김호중
# 100위: 압구정로데오 [ 압구정로데오 ] - 허각
